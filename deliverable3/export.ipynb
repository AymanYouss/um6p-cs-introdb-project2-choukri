# %%
import pandas as pd

# %%
df = pd.read_csv("table-dzfd.csv")

df
# Out:
#    region       tdate  country discharging_port delivery_mode customer_name  \
# 0  region  2003-11-11  morocco             casa     transport           ana
# 1  ldsnjs  1111-11-11      dsf              jtf            yg          ligy
# 2  ldsnjs  1111-11-11      dsf              jtf            yg          ligy
#
#   customer_group category  pid          pallets  ... storage_cost3  \
# 0            ana      mcp  213  1 pallet per BB  ...             0
# 1             li       ug    0              iug  ...             0
# 2             li       ug    0              iug  ...             0
#
#    jours_half  jours_1 jours_2 jours_3  ac_status contract_id  \
# 0           0        0       0       0        NaN           0
# 1           0        0       0       0        NaN           0
# 2           0        0       0       0        NaN           0
#
#    contract_status  invoice  Payment_status
# 0              NaN        0            Paid
# 1              NaN        0        Not Paid
# ...

# %%
df.to_excel("table.xlsx")
